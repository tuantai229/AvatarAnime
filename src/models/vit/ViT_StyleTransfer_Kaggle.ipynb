# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/19901_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/47071_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/823_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/16836_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/37175_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58761_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58395_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/30919_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/11352_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/23582_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/36898_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/60582_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/31736_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/36882_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56217_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/8839_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/52820_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/27154_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/51034_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/30438_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56130_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/21171_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/57964_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/4364_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/3335_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/26288_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56122_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/44593_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/30691_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58004_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/15729_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/4253_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/40417_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/52840_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/7811_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/42322_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/37378_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/34413_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/37120_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/52267_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/31351_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/39535_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/792_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/57350_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58024_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/59959_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/42816_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/25445_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/36475_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/57338_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/25509_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/17025_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/42827_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/41819_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/8121_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/40583_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56945_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/45318_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/29431_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56986_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/34409_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/35371_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/31634_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/35315_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/53860_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/46692_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/62939_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/51938_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/41799_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/41087_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/60561_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58007_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/1745_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/32202_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/56479_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/6674_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/63551_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/4174_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/37248_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/8523_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/32942_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/30032_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/55459_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/45006_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/15816_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/30560_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/53045_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/58498_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/11399_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/31301_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/27734_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/47669_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/12020_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/52668_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/17580_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/60567_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/33434_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/52985_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/48703_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/val/27615_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/45729_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/38553_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/13350_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/9921_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/5759_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/19507_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/44527_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/38577_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/42134_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/48999_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/43717_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/40409_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/60575_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/41750_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37272_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/58146_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/42199_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18327_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37308_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/54200_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/31580_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/21158_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/34880_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/17991_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/21697_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/57416_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/55555_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/61873_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/38538_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/52070_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37915_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/34935_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37622_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/57521_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/16479_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/52452_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/7256_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/20133_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/45304_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/13178_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/23215_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/45794_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/35975_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18037_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/7251_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/24422_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/12057_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/46323_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2934_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/30893_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/29182_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/39712_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/208_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37845_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/8536_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/45013_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/22861_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/63059_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18152_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18000_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/19810_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/21017_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18226_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/52892_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/805_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/39530_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/47148_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/28521_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/53595_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/45884_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/20082_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2598_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/27262_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/14446_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/19541_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/38981_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/19739_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/54865_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/18006_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/41401_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/58612_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/28970_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/30318_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/50324_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/19615_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/30689_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/56187_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/740_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/38033_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/60884_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/61913_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/55449_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/14748_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/11202_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/30719_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/37982_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/23042_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/55831_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/49246_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11579_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59162_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16074_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/9117_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27005_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23887_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29250_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/63129_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45466_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23126_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32483_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31362_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24311_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/51159_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30659_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55759_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54066_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42605_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/917_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50497_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8034_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31910_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54596_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45599_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10443_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44085_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43222_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32333_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55494_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46082_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11557_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52195_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52650_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61605_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25523_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57747_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48809_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59189_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34020_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20475_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21947_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46339_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38325_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43054_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21527_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/661_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37975_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1974_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1179_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15774_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38194_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57585_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46328_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37587_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29920_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/39924_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/930_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/216_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27545_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34223_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29532_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/39756_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60368_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50072_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57625_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60312_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11002_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2282_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1228_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1402_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46592_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26289_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/22961_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56520_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62830_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/13978_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56254_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3866_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/35631_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59747_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/13128_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58439_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24781_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40089_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24506_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21948_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60809_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27019_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45775_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16124_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28790_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25537_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48176_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40289_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37583_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38381_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46924_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17997_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/14091_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49741_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29423_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25847_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27357_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40558_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31911_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44662_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49990_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33059_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47173_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37449_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49940_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46440_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6889_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60317_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29245_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17831_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15157_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1008_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/36061_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3489_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6504_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/53541_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/5110_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48331_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32870_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56864_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16660_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/35558_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38741_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16946_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23538_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17100_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25561_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/5882_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17373_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6782_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47487_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61536_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34649_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19913_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/13424_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8239_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30615_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/5350_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34951_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/63363_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58434_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61115_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29382_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49371_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19999_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10119_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/12626_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29375_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1615_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20697_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45712_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52217_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60359_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46578_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54601_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/36281_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/830_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50548_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/39657_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52092_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48576_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4579_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32553_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4817_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59686_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16519_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60956_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20064_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61014_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45754_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8358_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45659_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/36527_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46009_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4945_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33410_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37910_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2765_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15977_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31241_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34027_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27970_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26815_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55219_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56650_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40423_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56721_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20729_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46601_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57298_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61099_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/18701_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/13069_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48382_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8169_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27318_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40048_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59124_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49644_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50323_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3264_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/36624_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1915_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10895_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8498_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/39226_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25114_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50929_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28931_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40102_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30517_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44006_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42916_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37875_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58469_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62277_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24355_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31240_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57575_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25388_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30633_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/41263_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26580_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48273_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8999_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34203_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6589_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56548_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17286_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58645_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26607_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30446_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43198_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50570_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44193_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15040_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45537_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48843_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28670_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15960_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26402_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/22586_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23723_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46878_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44523_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34529_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43074_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48159_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28516_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27038_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32702_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24605_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20144_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61330_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16188_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2056_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2382_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28979_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31641_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16249_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25288_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48037_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59290_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58586_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33661_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10943_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2444_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38564_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3928_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23971_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62586_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42249_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24112_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55302_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/60472_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19626_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1519_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/30274_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33830_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/63552_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40903_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1416_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55182_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15604_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23940_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59370_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59334_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/27081_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59289_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61771_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49521_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10270_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42784_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/5248_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58222_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47827_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26959_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24133_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19395_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29153_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43971_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2252_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15719_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32630_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59239_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/45588_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61239_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4968_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4992_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16337_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8762_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54577_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/7762_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/9802_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37400_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46048_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52577_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/5765_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33678_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46402_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57977_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/51263_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19806_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61064_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29034_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15434_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33024_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55036_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37338_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57868_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8222_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10129_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44836_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50332_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61042_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20437_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/837_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59464_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/7851_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61860_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55212_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32259_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25854_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43178_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28989_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2499_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48271_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/9513_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20313_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/7939_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8233_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15643_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25725_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/51990_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58451_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/13130_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1048_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6911_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43752_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/51831_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58715_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/7265_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26865_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62560_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34398_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55148_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58037_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/41399_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38609_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37232_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31379_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3694_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33256_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/36320_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/15002_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55989_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25269_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/22894_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44711_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2131_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40616_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46853_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46159_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/52310_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57464_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28725_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/10736_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32484_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23947_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/22230_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44254_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42080_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/49214_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19322_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/58866_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/14212_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54756_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/16014_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/59368_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43383_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54145_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/9725_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50401_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3670_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34704_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/46134_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/56544_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4784_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/35401_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1837_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1010_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/146_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55313_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/12977_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21070_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/8252_2004.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6067_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/6088_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28273_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40873_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61797_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/19156_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11668_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33142_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21344_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33409_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62807_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42239_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44014_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/14914_2006.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33950_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23528_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/41742_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/39330_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/12356_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47037_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20692_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20761_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/55984_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/37904_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23695_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/42440_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/268_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/23750_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32496_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/57057_2017.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/1050_2000.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/32272_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44138_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/20510_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4384_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25898_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48221_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/22835_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/48950_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25757_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/53413_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3383_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11630_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25793_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/53579_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24461_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/41658_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/50976_2015.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/26972_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17632_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/17494_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/11865_2005.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/21620_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/53207_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/2015_2001.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/29760_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/61314_2018.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/54563_2016.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/3917_2002.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47155_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24951_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62045_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/33035_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/47115_2014.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/31316_2010.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/62352_2019.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/34509_2011.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/41224_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/4632_2003.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/43199_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24036_2008.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/18079_2007.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40618_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/25468_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/44454_2013.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/24496_2009.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/40298_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/38583_2012.jpg
# /kaggle/input/avataranime/AvatarAnime/AnimeFace/train/28308_2009.jpg
# ...
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/042721.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/072401.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/193239.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/080986.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/086318.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/181288.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/000010.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/071758.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/058646.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/133357.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/022929.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087486.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/107706.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/056673.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/130969.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/179133.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/085224.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/094481.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/189276.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/172962.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/138415.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/163184.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/046358.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/059340.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/145370.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/083576.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/172806.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/016472.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087740.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/111555.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/148439.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/034175.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/045160.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/164861.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/146306.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/137669.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/199631.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/124923.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/175944.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/166568.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/076427.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/128728.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/175461.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/057684.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/149661.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/041547.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/081702.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/175827.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/137064.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/167521.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/078397.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/189106.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/103737.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/122799.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/119047.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/000913.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/069972.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/201212.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/109472.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/003815.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/126235.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/130360.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/195474.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/079938.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/105224.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/131803.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/131758.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/117101.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/199613.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/023077.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/168516.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/108939.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/042403.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/007959.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/035630.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/061555.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/065374.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/075057.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/088815.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/055231.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/133835.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/082874.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/083928.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/012498.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/164062.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/013170.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/178864.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/146901.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/161942.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/074947.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/169629.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/075074.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/055666.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/098147.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/200184.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/065771.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/198720.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/156629.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/084818.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/147986.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/054905.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/148928.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/080190.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/145412.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/077134.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/010072.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/093764.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/170159.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/021244.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/170666.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/057065.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/041866.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/072146.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/192656.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/167295.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/145065.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/106730.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/013819.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/018376.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/088745.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/118212.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/055319.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/036385.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/005851.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/145629.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/054857.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/044355.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/192970.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/006253.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/128125.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/088416.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/025718.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/018878.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/016910.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/097935.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/043491.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/131987.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/170003.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/188944.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/194715.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/184407.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/123843.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/131727.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/039152.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/064291.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/118053.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/072785.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087961.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/187711.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/030282.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/108639.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/056493.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/071862.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/014626.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/057354.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/133523.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/164190.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/029536.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/039372.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/150020.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/053288.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/138738.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/060040.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/140039.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/106961.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/106406.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/029962.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/173321.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/114242.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/201390.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087826.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/108129.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/130022.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/091258.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/168284.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/101193.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/167346.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/076662.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/001735.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/165005.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/052999.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/033641.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/084019.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/167297.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/178786.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/103549.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/199349.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/034751.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/077559.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/012403.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/119278.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/143948.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/140735.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/155308.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/110848.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/035463.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/022259.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/089307.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/109763.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/075285.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/001969.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/117778.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/063095.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/066135.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/064999.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/028288.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/141300.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/144100.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/102122.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/094195.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/075521.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/074008.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/163828.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/080281.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/158728.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087196.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/098528.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/105543.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/164748.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/181680.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/144272.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/038634.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/022520.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/134218.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/182207.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/166328.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/067153.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/065809.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/127941.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/182158.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/008279.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/038748.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/017592.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/008693.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/061188.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/136197.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/065261.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/087370.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/012293.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/139647.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/193327.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/094965.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/110038.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/070476.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/116804.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/049074.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/184610.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/109948.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/122252.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/175391.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/136778.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/035316.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/112693.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/076864.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/056922.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/186811.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/081064.jpg
# /kaggle/input/avataranime/AvatarAnime/CelebA/train/092356.jpg

# %%
# -*- coding: utf-8 -*-
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torchvision.models import vgg19, VGG19_Weights
from PIL import Image
import os
import matplotlib.pyplot as plt
import time
from tqdm.notebook import tqdm
import timm # Thư viện chứa các mô hình pre-trained, bao gồm ViT

# %%
# --- 1. Thiết lập cơ bản và Hằng số ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# --- 2. Định nghĩa Hằng số và Transforms ---
IMG_SIZE = 224 # Kích thước ảnh thống nhất
# Mean/Std của ImageNet (quan trọng khi dùng model pre-trained)
IMG_MEAN = [0.485, 0.456, 0.406]
IMG_STD = [0.229, 0.224, 0.225]

# Transforms cho huấn luyện (có augmentation)
train_transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),          # Resize về kích thước cố định trước
    transforms.RandomCrop(IMG_SIZE),      # Crop ngẫu nhiên về đúng kích thước
    transforms.RandomHorizontalFlip(),    # Lật ngang ngẫu nhiên
    transforms.ToTensor(),                # Chuyển thành tensor [0, 1]
    transforms.Normalize(mean=IMG_MEAN, std=IMG_STD) # Chuẩn hóa
])

# Transforms cho validation/test (không augmentation ngẫu nhiên)
test_transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),          # Resize về kích thước cố định
    transforms.CenterCrop(IMG_SIZE),      # Crop giữa về đúng kích thước
    transforms.ToTensor(),                # Chuyển thành tensor [0, 1]
    transforms.Normalize(mean=IMG_MEAN, std=IMG_STD) # Chuẩn hóa
])

# Hàm để denormalize ảnh khi hiển thị (chuyển từ tensor chuẩn hóa về ảnh xem được)
def denormalize(tensor, mean=IMG_MEAN, std=IMG_STD):
    # Clone để không ảnh hưởng tensor gốc
    tensor = tensor.clone().to('cpu')
    # Đảm bảo mean và std có đúng số chiều để broadcasting
    mean_tensor = torch.tensor(mean).view(1, 3, 1, 1)
    std_tensor = torch.tensor(std).view(1, 3, 1, 1)
    # Áp dụng công thức ngược: output = (input * std) + mean
    tensor.mul_(std_tensor).add_(mean_tensor)
    # Kẹp giá trị về [0, 1] phòng trường hợp có sai số nhỏ
    tensor = torch.clamp(tensor, 0, 1)
    return tensor

# %%
# --- 3. Custom Dataset ---
class CustomImageDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        try:
            # Lấy danh sách tất cả các file ảnh hợp lệ
            self.image_files = [f for f in os.listdir(root_dir)
                                if os.path.isfile(os.path.join(root_dir, f))
                                and f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
            if not self.image_files:
                print(f"Warning: No valid image files found in {root_dir}")
        except FileNotFoundError:
             print(f"Error: Directory not found {root_dir}")
             self.image_files = []
        except Exception as e:
            print(f"Error reading directory {root_dir}: {e}")
            self.image_files = []


    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        if idx >= len(self.image_files):
             raise IndexError("Index out of bounds")
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        try:
            image = Image.open(img_path).convert('RGB') # Đảm bảo ảnh là RGB
        except Exception as e:
            print(f"Error loading image {img_path}: {e}. Returning black image.")
            # Trả về ảnh đen nếu lỗi load
            image = Image.new('RGB', (IMG_SIZE, IMG_SIZE), (0, 0, 0))

        if self.transform:
            image = self.transform(image)

        # Trả về ảnh và nhãn dummy (không dùng trong style transfer)
        return image, 0

# %%
# --- 4. Định nghĩa các thành phần Model ---

# Hàm tính Mean/Std (Không inplace)
def calc_mean_std(features, eps=1e-5):
    batch_size, num_channels = features.size()[:2]
    # .var() và .mean() không phải inplace
    feature_var = features.view(batch_size, num_channels, -1).var(dim=2) + eps
    feature_std = feature_var.sqrt().view(batch_size, num_channels, 1, 1) # .sqrt() không inplace
    feature_mean = features.view(batch_size, num_channels, -1).mean(dim=2).view(batch_size, num_channels, 1, 1)
    return feature_mean, feature_std

# Hàm AdaIN (Không inplace)
def adaptive_instance_normalization(content_feat, style_feat):
    assert content_feat.size()[:2] == style_feat.size()[:2], "Batch size and channels must match"
    size = content_feat.size()
    style_mean, style_std = calc_mean_std(style_feat)
    content_mean, content_std = calc_mean_std(content_feat)
    # Các phép toán +, -, *, / tạo tensor mới, .expand() tạo view (an toàn)
    normalized_feat = (content_feat - content_mean.expand(size)) / content_std.expand(size)
    return normalized_feat * style_std.expand(size) + style_mean.expand(size)

# Decoder (Đảm bảo KHÔNG dùng inplace=True)
class Decoder(nn.Module):
    def __init__(self, input_dim, output_channels=3):
        super().__init__()
        self.model = nn.Sequential(
            # Input: B, C, 14, 14 -> Output: B, 3, 224, 224
            nn.ConvTranspose2d(input_dim, 512, kernel_size=3, stride=2, padding=1, output_padding=1), # 14->28
            nn.InstanceNorm2d(512),
            nn.ReLU(), # KHÔNG inplace=True
            nn.ConvTranspose2d(512, 256, kernel_size=3, stride=2, padding=1, output_padding=1), # 28->56
            nn.InstanceNorm2d(256),
            nn.ReLU(), # KHÔNG inplace=True
            nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, output_padding=1), # 56->112
            nn.InstanceNorm2d(128),
            nn.ReLU(), # KHÔNG inplace=True
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, output_padding=1), # 112->224
            nn.InstanceNorm2d(64),
            nn.ReLU(), # KHÔNG inplace=True
            # Lớp cuối cùng: Conv2d để giữ kích thước 224x224
            nn.Conv2d(64, output_channels, kernel_size=3, stride=1, padding=1),
            nn.Tanh() # Output trong khoảng [-1, 1]
        )

    def forward(self, x):
        return self.model(x)

# --- Mạng Style Transfer Chính ---
class ViTStyleTransfer(nn.Module):
    def __init__(self, vit_model_name='vit_base_patch16_224', vgg_weights=VGG19_Weights.DEFAULT):
        super().__init__()
        # 1. Encoder (ViT)
        self.vit_encoder = timm.create_model(vit_model_name, pretrained=True)
        self.embed_dim = self.vit_encoder.embed_dim
        self.vit_encoder.head = nn.Identity() # Bỏ lớp classification head
        # Lưu kích thước grid của patch embedding
        self.feature_map_size = self.vit_encoder.patch_embed.grid_size

        # 2. Decoder
        self.decoder = Decoder(input_dim=self.embed_dim)

        # 3. VGG Loss Network (Frozen)
        self.vgg_loss_net = self.load_vgg_for_loss(weights=vgg_weights)
        # Layer indices cho VGG19 features (thường dùng các lớp ReLU đầu mỗi block)
        # Ví dụ: relu1_1, relu2_1, relu3_1, relu4_1, relu5_1
        self.vgg_loss_layer_indices = [1, 6, 11, 20, 29] # Kiểm tra lại với print(vgg19(weights=...).features)

    def load_vgg_for_loss(self, weights):
        """Tải VGG19 pre-trained và đóng băng các tham số."""
        vgg = vgg19(weights=weights).features
        # Đóng băng tất cả tham số của VGG
        for param in vgg.parameters():
            param.requires_grad = False
        vgg.eval() # Đặt VGG ở chế độ eval
        print("Loaded VGG19 for loss calculation. Frozen.")
        # print(vgg) # Bỏ comment để xem cấu trúc và indices
        return vgg.to(device) # Chuyển VGG loss net sang device luôn

    def get_vit_features(self, x):
        """Trích xuất patch embeddings từ ViT và reshape."""
        B = x.shape[0]
        x = self.vit_encoder.patch_embed(x) # B, num_patches, embed_dim

        # Thêm positional embedding (bỏ qua CLS token embedding nếu có)
        # Kiểm tra xem pos_embed có bao gồm CLS token không
        cls_token_present = hasattr(self.vit_encoder, 'cls_token') and self.vit_encoder.cls_token is not None
        if cls_token_present and self.vit_encoder.pos_embed.shape[1] == x.shape[1] + 1:
            pos_embed_used = self.vit_encoder.pos_embed[:, 1:, :] # Bỏ qua pos_embed của CLS
        else:
            pos_embed_used = self.vit_encoder.pos_embed[:, :, :] # Dùng hết pos_embed (nếu không có CLS hoặc shape khớp)
            if pos_embed_used.shape[1] != x.shape[1]:
                 print(f"Warning: Positional embedding shape {pos_embed_used.shape} might not match patch embedding shape {x.shape}. Adjusting...")
                 # Cố gắng resize hoặc điều chỉnh nếu cần - phức tạp, nên kiểm tra kỹ model ViT
                 pos_embed_used = pos_embed_used[:, :x.shape[1], :] # Cách xử lý đơn giản, có thể không tối ưu

        x = x + pos_embed_used
        if hasattr(self.vit_encoder, 'pos_drop'):
             x = self.vit_encoder.pos_drop(x)

        # Đi qua các block Transformer
        for blk in self.vit_encoder.blocks:
            x = blk(x)

        x = self.vit_encoder.norm(x) # LayerNorm cuối

        # Reshape thành feature map: (B, num_patches, embed_dim) -> (B, embed_dim, H, W)
        num_patches = x.shape[1]
        H, W = self.feature_map_size
        if H * W != num_patches:
             raise ValueError(f"Feature map size {H}x{W} does not match number of patches {num_patches}")
        x = x.permute(0, 2, 1).contiguous().view(B, self.embed_dim, H, W)
        return x

    def forward(self, content_img, style_img):
        """Quy trình forward: encode -> adain -> decode."""
        content_features = self.get_vit_features(content_img)
        style_features = self.get_vit_features(style_img)
        stylized_features = adaptive_instance_normalization(content_features, style_features)
        output_img = self.decoder(stylized_features)
        return output_img

    def get_vgg_loss_features(self, image):
        """Trích xuất features từ các lớp VGG đã chọn."""
        features = []
        x = image
        for i, layer in enumerate(self.vgg_loss_net):
            x = layer(x)
            if i in self.vgg_loss_layer_indices:
                features.append(x)
        return features

    def calculate_loss(self, generated_img, content_img, style_img):
        """Tính toán content loss và style loss sử dụng VGG features."""
        mse_loss = nn.MSELoss()

        # Trích xuất features từ ảnh tạo ra (cần grad)
        gen_vgg_features = self.get_vgg_loss_features(generated_img)

        # Trích xuất features từ ảnh gốc (KHÔNG cần grad qua đây)
        # Sử dụng torch.no_grad() để đảm bảo không có gradient không mong muốn
        with torch.no_grad():
            content_vgg_features = self.get_vgg_loss_features(content_img)
            style_vgg_features = self.get_vgg_loss_features(style_img)

        # Content Loss (thường dùng 1 lớp sâu, ví dụ lớp thứ 3 hoặc 4 trong list indices)
        content_loss_target_layer_index = 2 # Ví dụ dùng relu3_1
        content_loss = mse_loss(gen_vgg_features[content_loss_target_layer_index],
                                content_vgg_features[content_loss_target_layer_index]) # Target đã trong no_grad

        # Style Loss (tính trên tất cả các lớp đã chọn)
        style_loss = 0
        for gen_feat, style_feat in zip(gen_vgg_features, style_vgg_features):
            # Tính mean/std cho features ảnh tạo ra (cần grad)
            gen_mean, gen_std = calc_mean_std(gen_feat)
            # Tính mean/std cho features ảnh style (target - không cần grad)
            style_mean, style_std = calc_mean_std(style_feat) # style_feat đã trong no_grad
            # Cộng dồn loss
            style_loss += mse_loss(gen_mean, style_mean) + mse_loss(gen_std, style_std)

        return content_loss, style_loss

# %%
# --- 5. Thiết lập đường dẫn và DataLoaders ---
content_dir_train = '/kaggle/input/avataranime/AvatarAnime/CelebA/train'
style_dir_train = '/kaggle/input/avataranime/AvatarAnime/AnimeFace/train'
content_dir_val = '/kaggle/input/avataranime/AvatarAnime/CelebA/val'
style_dir_val = '/kaggle/input/avataranime/AvatarAnime/AnimeFace/val'

# Kiểm tra sự tồn tại của thư mục
for path in [content_dir_train, style_dir_train, content_dir_val, style_dir_val]:
    if not os.path.isdir(path):
        print(f"FATAL ERROR: Directory not found - {path}. Please check the path.")
        # Có thể dừng script ở đây nếu muốn
        # raise FileNotFoundError(f"Directory not found: {path}")

# Tạo datasets với CustomImageDataset
print(f"Loading Content Train data from: {content_dir_train}")
content_dataset_train = CustomImageDataset(content_dir_train, transform=train_transform)
print(f"Found {len(content_dataset_train)} content train images.")

print(f"Loading Style Train data from: {style_dir_train}")
style_dataset_train = CustomImageDataset(style_dir_train, transform=train_transform)
print(f"Found {len(style_dataset_train)} style train images.")

print(f"Loading Content Validation data from: {content_dir_val}")
content_dataset_val = CustomImageDataset(content_dir_val, transform=test_transform)
print(f"Found {len(content_dataset_val)} content validation images.")

print(f"Loading Style Validation data from: {style_dir_val}")
style_dataset_val = CustomImageDataset(style_dir_val, transform=test_transform)
print(f"Found {len(style_dataset_val)} style validation images.")

# Kiểm tra dataset có dữ liệu không
if len(content_dataset_train) == 0 or len(style_dataset_train) == 0:
     raise ValueError("Training dataset(s) are empty. Check paths and image files.")
if len(content_dataset_val) == 0 or len(style_dataset_val) == 0:
     print("Warning: Validation dataset(s) are empty.")

# Tạo DataLoaders
BATCH_SIZE = 8 # Giảm nếu gặp lỗi CUDA out of memory
NUM_WORKERS = 2 # Số worker cho DataLoader
content_loader_train = DataLoader(content_dataset_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True, drop_last=True)
style_loader_train = DataLoader(style_dataset_train, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS, pin_memory=True, drop_last=True)
content_loader_val = DataLoader(content_dataset_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)
style_loader_val = DataLoader(style_dataset_val, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, pin_memory=True)

print("DataLoaders created.")
# Out:
# Loading Content Train data from: /kaggle/input/avataranime/AvatarAnime/CelebA/train
# Found 800 content train images.
# Loading Style Train data from: /kaggle/input/avataranime/AvatarAnime/AnimeFace/train
# Found 800 style train images.
# Loading Content Validation data from: /kaggle/input/avataranime/AvatarAnime/CelebA/val
# Found 100 content validation images.
# Loading Style Validation data from: /kaggle/input/avataranime/AvatarAnime/AnimeFace/val
# Found 100 style validation images.
# DataLoaders created.

# %%
# --- 6. Khởi tạo Model, Optimizer ---
print("Initializing Model and Optimizer...")
model = ViTStyleTransfer(vit_model_name='vit_base_patch16_224').to(device) # Chuyển model gốc sang device chính trước

# KIỂM TRA VÀ SỬ DỤNG DATAPARALLEL NẾU CÓ NHIỀU GPU
if torch.cuda.device_count() > 1:
  print(f"Let's use {torch.cuda.device_count()} GPUs!")
  # device_ids có thể được chỉ định rõ ràng, ví dụ [0, 1]
  # Nếu không chỉ định, nó sẽ dùng tất cả GPU khả dụng
  model = nn.DataParallel(model)
  # Lưu ý: DataParallel sẽ tự động chuyển model.module sang các device_ids được chỉ định
  # nhưng model gốc (đã được bọc) vẫn cần được to(device) (device chính, thường là cuda:0)
  # Trong trường hợp này, model đã được to(device) trước đó.

# Optimizer vẫn khởi tạo bình thường, nhưng với model.parameters()
# Nếu model được bọc bởi DataParallel, nên dùng model.module.parameters()
# nếu muốn truy cập tham số của model gốc, tuy nhiên,
# optimizer(model.parameters()) vẫn hoạt động vì DataParallel chuyển tiếp việc truy cập này.
optimizer = optim.AdamW(
    model.parameters(), # DataParallel xử lý việc này đúng cách
    lr=1e-4
)

print("Model and Optimizer initialized.")
# Nếu model được bọc DataParallel, khi lưu và load checkpoint, cần lưu ý:
# - Khi lưu: torch.save(model.module.state_dict(), PATH)
# - Khi load: model_goc.load_state_dict(torch.load(PATH)), sau đó mới bọc DataParallel nếu cần
# Out:
# Initializing Model and Optimizer...
# Loaded VGG19 for loss calculation. Frozen.
# Let's use 2 GPUs!
# Model and Optimizer initialized.

# %%
# prompt: remove /kaggle/working/ViT_StyleTransfer directory

import shutil
import os

# Define the directory to remove
dir_to_remove = '/kaggle/working/ViT_StyleTransfer'

# Check if the directory exists
if os.path.exists(dir_to_remove):
  try:
    # Use shutil.rmtree to remove the directory and its contents
    shutil.rmtree(dir_to_remove)
    print(f"Directory '{dir_to_remove}' and its contents removed successfully.")
  except OSError as e:
    print(f"Error: {e.filename} - {e.strerror}.")
else:
  print(f"Directory '{dir_to_remove}' does not exist.")
# Out:
# Directory '/kaggle/working/ViT_StyleTransfer' and its contents removed successfully.

# %%
# --- 7. Training Loop ---
NUM_EPOCHS = 50
LAMBDA_CONTENT = 3.0
LAMBDA_STYLE = 1.0 # Tỉ lệ style loss so với content loss

# Thư mục lưu kết quả
output_dir = '/kaggle/working/ViT_StyleTransfer' # Đổi tên để tránh ghi đè
checkpoint_dir = os.path.join(output_dir, 'checkpoints')
results_dir = os.path.join(output_dir, 'results')
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(results_dir, exist_ok=True)

# Bật anomaly detection để tìm lỗi cụ thể nếu có (có thể làm chậm quá trình huấn luyện)
# torch.autograd.set_detect_anomaly(True)

print("Starting Training...")
for epoch in range(NUM_EPOCHS):
    model.train() # Đặt model ở chế độ train
    epoch_start_time = time.time()
    running_content_loss = 0.0
    running_style_loss = 0.0
    running_total_loss = 0.0

    # Lấy số batch tối thiểu giữa 2 loader để tránh lỗi index
    num_batches = min(len(content_loader_train), len(style_loader_train))
    # Tạo iterator vô hạn cho style loader để đảm bảo luôn có style image
    style_iterator = iter(style_loader_train)

    pbar = tqdm(enumerate(content_loader_train), total=num_batches, desc=f"Epoch {epoch+1}/{NUM_EPOCHS}")

    for i, (content_batch, _) in pbar:
        if i >= num_batches: # Dừng epoch nếu đã đi qua số batch tối thiểu
             break

        # Lấy style batch, quay vòng nếu cần
        try:
            style_batch, _ = next(style_iterator)
        except StopIteration:
            style_iterator = iter(style_loader_train) # Reset iterator
            style_batch, _ = next(style_iterator)

        # Chuyển dữ liệu lên device
        content_images = content_batch.to(device)
        style_images = style_batch.to(device)

        # --- Forward Pass ---
        optimizer.zero_grad() # Xóa gradient cũ
        generated_images = model(content_images, style_images)

        # --- Loss Calculation ---
        if isinstance(model, nn.DataParallel):
            content_loss, style_loss = model.module.calculate_loss(generated_images, content_images, style_images)
        else:
            content_loss, style_loss = model.calculate_loss(generated_images, content_images, style_images)
        total_loss = LAMBDA_CONTENT * content_loss + LAMBDA_STYLE * style_loss

        # --- Backward Pass and Optimize ---
        # Kiểm tra loss có phải NaN không
        if torch.isnan(total_loss):
            print(f"Warning: NaN loss detected at batch {i}. Skipping backward pass.")
            # Cân nhắc dừng huấn luyện hoặc giảm learning rate nếu xảy ra thường xuyên
            continue # Bỏ qua batch này

        total_loss.backward() # Tính gradient
        optimizer.step()      # Cập nhật trọng số

        # --- Logging ---
        running_content_loss += content_loss.item()
        running_style_loss += style_loss.item()
        running_total_loss += total_loss.item()

        # Cập nhật progress bar
        pbar.set_postfix({
            'Content L': f"{content_loss.item():.3f}",
            'Style L': f"{style_loss.item():.3f}",
            'Total L': f"{total_loss.item():.3f}"
        })

    # --- End of Epoch ---
    avg_content_loss = running_content_loss / num_batches if num_batches > 0 else 0
    avg_style_loss = running_style_loss / num_batches if num_batches > 0 else 0
    avg_total_loss = running_total_loss / num_batches if num_batches > 0 else 0
    epoch_duration = time.time() - epoch_start_time

    print(f"\nEpoch {epoch+1} Summary: Avg Loss (Total: {avg_total_loss:.4f}, Content: {avg_content_loss:.4f}, Style: {avg_style_loss:.4f}), Time: {epoch_duration:.2f}s")

    # --- Validation and Visualization ---
    model.eval() # Đặt model ở chế độ eval
    with torch.no_grad(): # Không tính gradient trong validation
        # Lấy một vài ảnh cố định từ validation set
        try:
             val_content_batch, _ = next(iter(content_loader_val))
             val_style_batch, _ = next(iter(style_loader_val))
        except StopIteration:
             print("Warning: Validation loader is empty, skipping visualization.")
             continue # Bỏ qua visualization nếu không có dữ liệu val

        val_content = val_content_batch[:4].to(device) # Lấy 4 ảnh đầu
        val_style = val_style_batch[:4].to(device)
        val_generated = model(val_content, val_style)

        # Denormalize để hiển thị
        val_content_vis = denormalize(val_content)
        val_style_vis = denormalize(val_style)
        val_generated_vis = denormalize(val_generated)

        # Vẽ và lưu ảnh
        fig, axes = plt.subplots(3, 4, figsize=(12, 9))
        fig.suptitle(f'Epoch {epoch+1} Validation Results', fontsize=16)
        for j in range(4):
            # Content
            axes[0, j].imshow(val_content_vis[j].permute(1, 2, 0))
            axes[0, j].set_title("Content")
            axes[0, j].axis('off')
            # Style
            axes[1, j].imshow(val_style_vis[j].permute(1, 2, 0))
            axes[1, j].set_title("Style")
            axes[1, j].axis('off')
            # Generated
            axes[2, j].imshow(val_generated_vis[j].permute(1, 2, 0))
            axes[2, j].set_title("Generated")
            axes[2, j].axis('off')
        plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
        save_path = os.path.join(results_dir, f'epoch_{epoch+1:03d}_validation.png')
        plt.savefig(save_path)
        # plt.show() # Hiển thị trong Colab output (có thể bỏ nếu chỉ cần lưu file)
        plt.close(fig) # Đóng figure để giải phóng bộ nhớ

    # --- Save Checkpoint ---
    if epoch%5 == 0:
        checkpoint_path = os.path.join(checkpoint_dir, f'model_epoch_{epoch+1:03d}.pth')
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'avg_total_loss': avg_total_loss,
            'avg_content_loss': avg_content_loss,
            'avg_style_loss': avg_style_loss,
        }, checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")

    # --- (Optional) Update Learning Rate Scheduler ---
    # if scheduler:
    #     scheduler.step(avg_total_loss)
    #     current_lr = optimizer.param_groups[0]['lr']
    #     print(f"Current LR: {current_lr}")

print("Training Finished!")

# Tắt anomaly detection sau khi huấn luyện xong
# torch.autograd.set_detect_anomaly(False)
# Out:
# Starting Training...
# Epoch 1/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1 Summary: Avg Loss (Total: 26.3829, Content: 5.8432, Style: 8.8534), Time: 80.83s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_001.pth
# Epoch 2/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 2 Summary: Avg Loss (Total: 21.6025, Content: 5.2423, Style: 5.8757), Time: 80.28s
# Epoch 3/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 3 Summary: Avg Loss (Total: 19.0779, Content: 4.5774, Style: 5.3457), Time: 79.90s
# Epoch 4/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 4 Summary: Avg Loss (Total: 16.7014, Content: 3.8911, Style: 5.0282), Time: 79.46s
# Epoch 5/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 5 Summary: Avg Loss (Total: 15.1536, Content: 3.4581, Style: 4.7794), Time: 79.76s
# Epoch 6/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 6 Summary: Avg Loss (Total: 14.0609, Content: 3.1453, Style: 4.6250), Time: 79.58s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_006.pth
# Epoch 7/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 7 Summary: Avg Loss (Total: 13.1504, Content: 2.8791, Style: 4.5132), Time: 79.90s
# Epoch 8/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 8 Summary: Avg Loss (Total: 12.4159, Content: 2.6593, Style: 4.4380), Time: 79.80s
# Epoch 9/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 9 Summary: Avg Loss (Total: 11.8817, Content: 2.4963, Style: 4.3929), Time: 79.68s
# Epoch 10/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 10 Summary: Avg Loss (Total: 11.3925, Content: 2.3552, Style: 4.3271), Time: 80.19s
# Epoch 11/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 11 Summary: Avg Loss (Total: 11.0439, Content: 2.2490, Style: 4.2970), Time: 80.07s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_011.pth
# Epoch 12/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 12 Summary: Avg Loss (Total: 10.7078, Content: 2.1555, Style: 4.2411), Time: 80.02s
# Epoch 13/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 13 Summary: Avg Loss (Total: 10.5013, Content: 2.0900, Style: 4.2313), Time: 79.75s
# Epoch 14/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 14 Summary: Avg Loss (Total: 10.2392, Content: 2.0214, Style: 4.1751), Time: 80.24s
# Epoch 15/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 15 Summary: Avg Loss (Total: 10.1281, Content: 1.9871, Style: 4.1669), Time: 79.52s
# Epoch 16/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 16 Summary: Avg Loss (Total: 9.9379, Content: 1.9380, Style: 4.1238), Time: 80.13s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_016.pth
# Epoch 17/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 17 Summary: Avg Loss (Total: 9.8083, Content: 1.8926, Style: 4.1304), Time: 79.51s
# Epoch 18/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 18 Summary: Avg Loss (Total: 9.6513, Content: 1.8462, Style: 4.1127), Time: 80.28s
# Epoch 19/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 19 Summary: Avg Loss (Total: 9.5532, Content: 1.8229, Style: 4.0844), Time: 80.13s
# Epoch 20/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 20 Summary: Avg Loss (Total: 9.4509, Content: 1.7896, Style: 4.0821), Time: 79.73s
# Epoch 21/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 21 Summary: Avg Loss (Total: 9.3987, Content: 1.7730, Style: 4.0796), Time: 79.45s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_021.pth
# Epoch 22/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 22 Summary: Avg Loss (Total: 9.2942, Content: 1.7478, Style: 4.0509), Time: 79.54s
# Epoch 23/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 23 Summary: Avg Loss (Total: 9.2192, Content: 1.7235, Style: 4.0486), Time: 79.70s
# Epoch 24/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 24 Summary: Avg Loss (Total: 9.1631, Content: 1.7100, Style: 4.0332), Time: 79.62s
# Epoch 25/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 25 Summary: Avg Loss (Total: 9.1082, Content: 1.6974, Style: 4.0160), Time: 80.25s
# Epoch 26/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 26 Summary: Avg Loss (Total: 9.0852, Content: 1.6910, Style: 4.0121), Time: 79.63s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_026.pth
# Epoch 27/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 27 Summary: Avg Loss (Total: 8.9495, Content: 1.6479, Style: 4.0056), Time: 79.67s
# Epoch 28/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 28 Summary: Avg Loss (Total: 8.8958, Content: 1.6346, Style: 3.9918), Time: 79.57s
# Epoch 29/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 29 Summary: Avg Loss (Total: 8.8312, Content: 1.6172, Style: 3.9796), Time: 79.78s
# Epoch 30/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 30 Summary: Avg Loss (Total: 8.7673, Content: 1.6050, Style: 3.9521), Time: 79.59s
# Epoch 31/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 31 Summary: Avg Loss (Total: 8.7344, Content: 1.5946, Style: 3.9506), Time: 80.21s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_031.pth
# Epoch 32/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 32 Summary: Avg Loss (Total: 8.6828, Content: 1.5803, Style: 3.9420), Time: 79.62s
# Epoch 33/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 33 Summary: Avg Loss (Total: 8.6642, Content: 1.5738, Style: 3.9429), Time: 79.57s
# Epoch 34/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 34 Summary: Avg Loss (Total: 8.5899, Content: 1.5541, Style: 3.9275), Time: 80.33s
# Epoch 35/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 35 Summary: Avg Loss (Total: 8.5505, Content: 1.5463, Style: 3.9117), Time: 79.55s
# Epoch 36/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 36 Summary: Avg Loss (Total: 8.5127, Content: 1.5332, Style: 3.9133), Time: 79.79s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_036.pth
# Epoch 37/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 37 Summary: Avg Loss (Total: 8.4803, Content: 1.5215, Style: 3.9157), Time: 79.71s
# Epoch 38/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 38 Summary: Avg Loss (Total: 8.4546, Content: 1.5158, Style: 3.9071), Time: 80.26s
# Epoch 39/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 39 Summary: Avg Loss (Total: 8.4030, Content: 1.5055, Style: 3.8865), Time: 79.77s
# Epoch 40/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 40 Summary: Avg Loss (Total: 8.3719, Content: 1.4953, Style: 3.8859), Time: 79.74s
# Epoch 41/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 41 Summary: Avg Loss (Total: 8.3310, Content: 1.4880, Style: 3.8668), Time: 79.75s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_041.pth
# Epoch 42/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 42 Summary: Avg Loss (Total: 8.3174, Content: 1.4827, Style: 3.8695), Time: 80.48s
# Epoch 43/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 43 Summary: Avg Loss (Total: 8.2700, Content: 1.4704, Style: 3.8589), Time: 79.89s
# Epoch 44/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 44 Summary: Avg Loss (Total: 8.4786, Content: 1.5290, Style: 3.8915), Time: 79.57s
# Epoch 45/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 45 Summary: Avg Loss (Total: 8.2539, Content: 1.4640, Style: 3.8618), Time: 80.71s
# Epoch 46/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 46 Summary: Avg Loss (Total: 8.2127, Content: 1.4587, Style: 3.8366), Time: 79.57s
# Checkpoint saved to /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_046.pth
# Epoch 47/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 47 Summary: Avg Loss (Total: 8.1494, Content: 1.4401, Style: 3.8291), Time: 79.61s
# Epoch 48/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 48 Summary: Avg Loss (Total: 8.1730, Content: 1.4436, Style: 3.8421), Time: 79.69s
# Epoch 49/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 49 Summary: Avg Loss (Total: 8.0825, Content: 1.4222, Style: 3.8158), Time: 80.61s
# Epoch 50/50:   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 50 Summary: Avg Loss (Total: 8.0908, Content: 1.4244, Style: 3.8176), Time: 79.78s
# Training Finished!

# %%
# --- 8. Inference Function ---
def run_inference(content_path, style_path, model_checkpoint_path, output_path):
    print(f"Running inference...")
    print(f"Content: {content_path}")
    print(f"Style: {style_path}")
    print(f"Checkpoint: {model_checkpoint_path}")

    try:
        # Thêm weights_only=True để tăng cường bảo mật và tránh warning
        checkpoint = torch.load(model_checkpoint_path, map_location=device, weights_only=True)
        
        # Khởi tạo model gốc
        inference_model = ViTStyleTransfer().to(device)
        
        # Lấy state_dict từ checkpoint
        state_dict_from_checkpoint = checkpoint['model_state_dict']
        
        # Kiểm tra và loại bỏ tiền tố 'module.' nếu có
        # Tạo một state_dict mới không có tiền tố 'module.'
        from collections import OrderedDict
        new_state_dict = OrderedDict()
        is_data_parallel_checkpoint = False
        for k, v in state_dict_from_checkpoint.items():
            if k.startswith('module.'):
                new_state_dict[k[7:]] = v # Loại bỏ 'module.' (7 ký tự)
                is_data_parallel_checkpoint = True
            else:
                new_state_dict[k] = v # Giữ nguyên nếu không có tiền tố
        
        if is_data_parallel_checkpoint:
            print("Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.")
            inference_model.load_state_dict(new_state_dict)
        else:
            print("Checkpoint was saved from a single GPU model or 'module.' prefix already removed.")
            inference_model.load_state_dict(state_dict_from_checkpoint) # Load trực tiếp

        inference_model.eval() # Đặt chế độ inference
        print(f"Loaded model from epoch {checkpoint.get('epoch', 'N/A')}")

    except Exception as e:
        print(f"Error loading checkpoint: {e}")
        return

    # Load và xử lý ảnh input
    try:
        content_img = Image.open(content_path).convert('RGB')
        style_img = Image.open(style_path).convert('RGB')
    except FileNotFoundError as e:
         print(f"Error opening image file: {e}")
         return
    except Exception as e:
         print(f"Error processing image file: {e}")
         return

    content_tensor = test_transform(content_img).unsqueeze(0).to(device)
    style_tensor = test_transform(style_img).unsqueeze(0).to(device)

    # Thực hiện style transfer
    with torch.no_grad():
        output_tensor = inference_model(content_tensor, style_tensor)

    # Denormalize và chuyển về PIL Image
    output_tensor_denorm = denormalize(output_tensor.cpu()) # Chuyển về CPU trước khi denorm
    output_img = transforms.ToPILImage()(output_tensor_denorm.squeeze(0)) # Bỏ chiều batch

    # Lưu ảnh kết quả
    try:
        output_img.save(output_path)
        print(f"Inference result saved to {output_path}")
        # display(output_img) # Hiển thị nếu chạy trong notebook
    except Exception as e:
        print(f"Error saving inference result: {e}")

# Sử dụng inference
print("\n--- Running Example Inference ---")
example_content = '/kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg' 
example_style = '/kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg'
for i in range(1, 51):
    example_checkpoint = os.path.join(checkpoint_dir, f'model_epoch_{i:03d}.pth') 
    example_output = os.path.join(results_dir, f'inference_example_output_{i:03d}.jpg')

    if os.path.exists(example_content) and os.path.exists(example_style) and os.path.exists(example_checkpoint):
        run_inference(example_content, example_style, example_checkpoint, example_output)
    else:
        print("Skipping example inference: Input files or checkpoint not found.")
# Out:
# --- Running Example Inference ---
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_001.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 1
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_001.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_006.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 6
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_006.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_011.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 11
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_011.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_016.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 16
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_016.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_021.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 21
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_021.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_026.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 26
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_026.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_031.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 31
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_031.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_036.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 36
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_036.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_041.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 41
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_041.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Running inference...
# Content: /kaggle/input/avataranime/AvatarAnime/CelebA/test/019692.jpg
# Style: /kaggle/input/avataranime/AvatarAnime/AnimeFace/test/2091_2001.jpg
# Checkpoint: /kaggle/working/ViT_StyleTransfer/checkpoints/model_epoch_046.pth
# Loaded VGG19 for loss calculation. Frozen.
# Checkpoint was saved from a DataParallel model. Removing 'module.' prefix.
# Loaded model from epoch 46
# Inference result saved to /kaggle/working/ViT_StyleTransfer/results/inference_example_output_046.jpg
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.
# Skipping example inference: Input files or checkpoint not found.

# %%
# !zip -r ViT_StyleTransfer_results.zip /kaggle/working/ViT_StyleTransfer/results
# Out:
#   adding: kaggle/working/ViT_StyleTransfer/results/ (stored 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_031.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_001.jpg (deflated 14%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_049_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_037_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_022_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_032_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_011.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_048_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_035_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_039_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_019_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_015_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_018_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_036.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_044_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_009_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_002_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_046_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_041_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_023_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_016_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_045_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_014_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_038_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_043_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_036_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_024_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_029_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_003_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_033_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_040_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_025_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_008_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_012_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_001_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_007_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_017_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_010_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_047_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_030_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_026_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_046.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_031_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_021.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_028_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_050_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_020_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_027_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_026.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_006.jpg (deflated 3%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_042_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_011_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_004_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_013_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_041.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_021_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/inference_example_output_016.jpg (deflated 2%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_034_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_005_validation.png (deflated 0%)
#   adding: kaggle/working/ViT_StyleTransfer/results/epoch_006_validation.png (deflated 0%)

# %%
from IPython.display import FileLink
FileLink(r'ViT_StyleTransfer_results.zip')
